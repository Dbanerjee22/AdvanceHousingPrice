# %% [markdown]
# ## Feature selection

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
train=pd.read_csv("D:\\DataSet\\AdvanceHousePrice\\X_train.csv")
test=pd.read_csv("D:\\DataSet\\AdvanceHousePrice\\X_test.csv")

# %%
train.head()
# Out:
#    SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0  12.247694    0.487992      0.75     0.418208  0.366344     1.0    1.0
# 1  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2  12.317167    0.487992      0.75     0.434909  0.422359     1.0    1.0
# 3  11.849398    0.556464      0.75     0.388581  0.390295     1.0    1.0
# 4  12.429216    0.487992      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  Utilities  ...  Fence  MiscFeature  MiscVal  \
# 0  0.000000     0.333333        1.0  ...    1.0          1.0      0.0
# 1  0.000000     0.333333        1.0  ...    1.0          1.0      0.0
# 2  0.333333     0.333333        1.0  ...    1.0          1.0      0.0
# 3  0.333333     0.333333        1.0  ...    1.0          1.0      0.0
# 4  0.333333     0.333333        1.0  ...    1.0          1.0      0.0
#
#      MoSold    YrSold  SaleType  SaleCondition  LotFrontageNaN  MasVnrAreaNaN  \
# ...

# %%
test.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    0.000000      0.50     0.495064  0.428726     1.0    1.0  0.000000
# 1    0.000000      0.75     0.499662  0.468857     1.0    1.0  0.333333
# 2    0.487992      0.75     0.466207  0.462769     1.0    1.0  0.333333
# 3    0.487992      0.75     0.485693  0.398875     1.0    1.0  0.333333
# 4    0.795881      0.75     0.265271  0.263841     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  ...  Fence  MiscFeature   MiscVal  \
# 0     0.333333        1.0       0.00  ...    0.5          1.0  0.000000
# 1     0.333333        1.0       0.25  ...    1.0          0.0  0.806452
# 2     0.333333        1.0       0.00  ...    0.5          1.0  0.000000
# 3     0.333333        1.0       0.00  ...    1.0          1.0  0.000000
# 4     1.000000        1.0       0.00  ...    1.0          1.0  0.000000
#
#      MoSold  YrSold  SaleType  SaleCondition  LotFrontageNaN  MasVnrAreaNaN  \
# ...

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    0.487992      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2    0.487992      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3    0.556464      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4    0.487992      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  ...  Fence  MiscFeature  MiscVal  \
# 0     0.333333        1.0       0.00  ...    1.0          1.0      0.0
# 1     0.333333        1.0       0.50  ...    1.0          1.0      0.0
# 2     0.333333        1.0       0.00  ...    1.0          1.0      0.0
# 3     0.333333        1.0       0.25  ...    1.0          1.0      0.0
# 4     0.333333        1.0       0.50  ...    1.0          1.0      0.0
#
#      MoSold    YrSold  SaleType  SaleCondition  LotFrontageNaN  MasVnrAreaNaN  \
# ...

# %%
y_train=train["SalePrice"]

# %%
X_train=train.drop(["SalePrice"],axis=1)

# %%
X_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    0.487992      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2    0.487992      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3    0.556464      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4    0.487992      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  ...  Fence  MiscFeature  MiscVal  \
# 0     0.333333        1.0       0.00  ...    1.0          1.0      0.0
# 1     0.333333        1.0       0.50  ...    1.0          1.0      0.0
# 2     0.333333        1.0       0.00  ...    1.0          1.0      0.0
# 3     0.333333        1.0       0.25  ...    1.0          1.0      0.0
# 4     0.333333        1.0       0.50  ...    1.0          1.0      0.0
#
#      MoSold    YrSold  SaleType  SaleCondition  LotFrontageNaN  MasVnrAreaNaN  \
# ...

# %%
# Out:
# BsmtQual 44
# BsmtExposure 44
# BsmtFullBath 2
# KitchenQual 1
# FireplaceQu 730
# GarageFinish 78
# GarageCars 1

# %%
feature_sel_model=SelectFromModel(estimator=Lasso(alpha=0.005,random_state=0))
feature_sel_model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False,  True,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False])

# %%
selected_feat=X_train.columns[(feature_sel_model.get_support())]
# let's print some stats
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(feature_sel_model.estimator_.coef_ == 0)))
# Out:
# total features: 82
# selected features: 20
# features with coefficients shrank to zero: 62

# %%
X_train=X_train[selected_feat]

# %%
X_test=test[selected_feat]

# %%
for feature in X_test:
    if X_test[feature].isnull().sum()>0:
        print(feature,X_test[feature].isnull().sum())

# %%
X_test.dropna(axis=0,how='any',inplace=True)
# Out:
# <ipython-input-98-b12af92f9428>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.dropna(axis=0,how='any',inplace=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.3, random_state=0)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(x_test)

# %%
sns.displot(prediction-y_test)

# %%
test_data_prediction=model.predict(X_test)

# %%
test_data_prediction
# Out:
# array([11.59127864, 11.91206177, 12.02053699, ..., 11.85729389,
#        11.61115734, 12.26149676])
